# %% [markdown]
# <a href="https://colab.research.google.com/github/writetomangamsudheer-stack/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skill sets needed to build and manage AI systems, from foundational data work to strategic oversight:
#
# *   **Data Foundation:** Skills in data acquisition, storage, cleaning, and preparation, forming the base for any AI project.
# *   **Model Development:** Expertise in feature engineering, selecting algorithms, training, validating, and optimizing AI/ML models.
# *   **Deployment & Operations:** Skills for integrating trained models into real-world applications, monitoring performance, and managing their lifecycle.
# *   **Strategy & Ethics:** High-level capabilities in defining AI goals, ensuring ethical implementation, aligning AI with business value, and governance.
