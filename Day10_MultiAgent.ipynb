# %% [markdown]
# <a href="https://colab.research.google.com/github/writetomangamsudheer-stack/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 799.2 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 48.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 57.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.5/822.5 kB 44.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 51.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 74.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.8/334.8 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 52.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 95.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 41.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 16.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:16:30 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:16:30 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0c879a7e-69ca-44e0-bcf0-25ef1047e15e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 246fdb6f-eb9a-4e1f-8a4b-e3676a54651c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **TCS Digital Placement Preparation for B.Tech Students**                                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment:** Typically includes sections on quantitative aptitude, verbal ability, logical       │
# │  reasoning, and advanced coding (often 1-2 challenging problems).                                               │
# │  *   **Technical Interview:** Focuses on data structures and algorithms, programming language proficiency,      │
# │  core CS subjects (OS, DBMS, Networking), and project discussions.                                              │
# │  *   **Managerial Interview:** Evaluates problem-solving approach, technical aptitude beyond code, leadership   │
# │  potential, and ability to handle project-specific scenarios.                                                   │
# │  *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and discusses           │
# │  compensation, location preferences, and joining formalities.                                                   │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Programming Languages:** Strong proficiency in Java, Python, or C++ with knowledge of associated         │
# │  frameworks (e.g., Spring Boot, Django/Flask).                                                                  │
# │  *   **Cloud Technologies:** Familiarity with AWS, Azure, or GCP services (e.g., compute, storage, serverless   │
# │  functions).                                                                                                    │
# │  *   **Data Science & AI/ML:** Understanding of machine learning concepts, data manipulation libraries          │
# │  (Pandas, NumPy), and ML frameworks (TensorFlow, PyTorch, Scikit-learn).                                        │
# │  *   **Web Technologies:** Knowledge of front-end frameworks (React, Angular, Vue.js) and back-end development  │
# │  principles.                                                                                                    │
# │  *   **Databases & DevOps:** Experience with SQL/NoSQL databases (e.g., MySQL, PostgreSQL, MongoDB) and basic   │
# │  DevOps concepts (Docker, Git).                                                                                 │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Percentage:** Generally requires a consistent academic record of 60% or 6.0 CGPA and above      │
# │  throughout 10th, 12th, and Graduation.                                                                         │
# │  *   **Degree:** Open to B.E./B.Tech/M.E./M.Tech/MCA students from specific branches (e.g., CSE, IT, ECE, EEE,  │
# │  Mechanical).                                                                                                   │
# │  *   **Year of Passing:** Primarily targets final-year students, but specific drives may include recent         │
# │  graduates.                                                                                                     │
# │  *   **Backlogs:** Candidates typically must not have any active backlogs at the time of appearing for the      │
# │  process.                                                                                                       │
# │  *   **Gap in Education:** A maximum academic gap of 1-2 years is usually permissible, but candidates should    │
# │  be prepared to explain it.                                                                                     │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Focus on Digital Skills:** Strong emphasis on candidates demonstrating proficiency in cutting-edge       │
# │  technologies relevant to digital transformation.                                                               │
# │  *   **Higher Compensation:** TCS Digital offers significantly higher compensation packages compared to TCS     │
# │  Ninja roles, reflecting demand for specialized skills.                                                         │
# │  *   **Problem-Solving Prowess:** Assessments increasingly prioritize advanced problem-solving, logical         │
# │  reasoning, and complex coding challenges.                                                                      │
# │  *   **Project-Based Evaluation:** More weight is given to real-world projects, internships, and                │
# │  certifications showcasing practical application of digital skills.                                             │
# │  *   **Agile & DevOps Mindset:** Recruiters look for candidates who understand agile methodologies and have an  │
# │  inclination towards DevOps practices.                                                                          │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA & Competitive Programming:** Consistently practice Data Structures and Algorithms on          │
# │  platforms like LeetCode, HackerRank, or CodeChef, focusing on medium to hard problems.                         │
# │  *   **Build Projects:** Develop 2-3 significant projects using modern technologies (web apps, AI/ML models,    │
# │  cloud deployments) to showcase practical skills.                                                               │
# │  *   **Deep Dive into Core CS:** Strengthen fundamentals in Operating Systems, Database Management Systems,     │
# │  Computer Networks, and Object-Oriented Programming (OOPs) concepts.                                            │
# │  *   **Learn a Niche Technology:** Specialize in one or two in-demand areas like Cloud (AWS/Azure/GCP), Data    │
# │  Science/ML, or Full-Stack Development.                                                                         │
# │  *   **Practice Mock Interviews:** Conduct mock technical and HR interviews to refine communication skills,     │
# │  articulate solutions clearly, and prepare for behavioral questions.                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: f676cb7c-d818-488a-a8db-de19b36839f9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Aiming for a rewarding career in cutting-edge tech? TCS Digital offers specialized roles, higher               │
# │  compensation, and a chance to innovate. Prepare smart, secure your future, and embark on a journey of digital  │
# │  transformation!                                                                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Road to TCS Digital: Hiring Process                                                                 │
# │                                                                                                                 │
# │  The selection process is designed to identify top digital talent. Be prepared for a multi-stage evaluation:    │
# │                                                                                                                 │
# │  *   **Online Assessment:** Covers Quantitative Aptitude, Verbal Ability, Logical Reasoning, and Advanced       │
# │  Coding (expect 1-2 challenging problems).                                                                      │
# │  *   **Technical Interview:** Deep dive into Data Structures & Algorithms (DSA), programming language           │
# │  proficiency (Java/Python/C++), core CS subjects (OS, DBMS, Networking), and in-depth discussions on your       │
# │  projects.                                                                                                      │
# │  *   **Managerial Interview:** Evaluates your problem-solving approach, technical aptitude beyond just coding,  │
# │  leadership potential, and ability to handle project-specific scenarios.                                        │
# │  *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and handles             │
# │  discussions on compensation, location preferences, and joining formalities.                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 2. Your Digital Toolkit: Technical Stack                                                                   │
# │                                                                                                                 │
# │  TCS Digital roles demand proficiency in modern technologies. Focus on building expertise in these areas:       │
# │                                                                                                                 │
# │  *   **Programming Languages:** Strong command over Java, Python, or C++ with knowledge of relevant frameworks  │
# │  (e.g., Spring Boot, Django/Flask).                                                                             │
# │  *   **Cloud Technologies:** Familiarity with services from AWS, Azure, or GCP (e.g., compute, storage,         │
# │  serverless functions).                                                                                         │
# │  *   **Data Science & AI/ML:** Understanding of machine learning concepts, data manipulation libraries          │
# │  (Pandas, NumPy), and ML frameworks (TensorFlow, PyTorch, Scikit-learn).                                        │
# │  *   **Web Technologies:** Knowledge of front-end frameworks (React, Angular, Vue.js) and back-end development  │
# │  principles.                                                                                                    │
# │  *   **Databases & DevOps:** Experience with SQL/NoSQL databases (e.g., MySQL, PostgreSQL, MongoDB) and basic   │
# │  DevOps concepts (Docker, Git).                                                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 3. Are You Eligible?                                                                                       │
# │                                                                                                                 │
# │  Ensure you meet the basic academic and background criteria:                                                    │
# │                                                                                                                 │
# │  *   **Academic Percentage:** A consistent record of 60% or 6.0 CGPA and above throughout 10th, 12th, and       │
# │  Graduation.                                                                                                    │
# │  *   **Degree:** Open to B.E./B.Tech/M.E./M.Tech/MCA students from specified branches (e.g., CSE, IT, ECE,      │
# │  EEE, Mechanical).                                                                                              │
# │  *   **Year of Passing:** Primarily targets final-year students, but specific drives may include recent         │
# │  graduates.                                                                                                     │
# │  *   **Backlogs:** Candidates must not have any active backlogs at the time of appearing for the process.       │
# │  *   **Gap in Education:** A maximum academic gap of 1-2 years is usually permissible, but be prepared to       │
# │  explain it clearly.                                                                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 4. What TCS Digital Looks For: Recent Hiring Trends                                                        │
# │                                                                                                                 │
# │  Understand the evolving expectations of TCS Digital recruiters:                                                │
# │                                                                                                                 │
# │  *   **Focus on Digital Skills:** Strong emphasis on candidates demonstrating proficiency in cutting-edge       │
# │  technologies relevant to digital transformation.                                                               │
# │  *   **Higher Compensation:** TCS Digital offers significantly higher packages compared to TCS Ninja roles,     │
# │  reflecting demand for specialized skills.                                                                      │
# │  *   **Problem-Solving Prowess:** Assessments increasingly prioritize advanced problem-solving, logical         │
# │  reasoning, and complex coding challenges.                                                                      │
# │  *   **Project-Based Evaluation:** More weight is given to real-world projects, internships, and                │
# │  certifications showcasing practical application of digital skills.                                             │
# │  *   **Agile & DevOps Mindset:** Recruiters seek candidates who understand agile methodologies and have an      │
# │  inclination towards DevOps practices.                                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 5. Your Winning Strategy: Prep Tips                                                                        │
# │                                                                                                                 │
# │  Craft a focused preparation plan to excel in the TCS Digital process:                                          │
# │                                                                                                                 │
# │  *   **Master DSA & Competitive Programming:** Consistently practice Data Structures and Algorithms on          │
# │  platforms like LeetCode, HackerRank, or CodeChef, focusing on medium to hard problems.                         │
# │  *   **Build Projects:** Develop 2-3 significant projects using modern technologies (e.g., web apps, AI/ML      │
# │  models, cloud deployments) to showcase practical skills.                                                       │
# │  *   **Deep Dive into Core CS:** Strengthen fundamentals in Operating Systems, Database Management Systems,     │
# │  Computer Networks, and Object-Oriented Programming (OOPs) concepts.                                            │
# │  *   **Learn a Niche Technology:** Specialize in one or two in-demand areas like Cloud (AWS/Azure/GCP), Data    │
# │  Science/ML, or Full-Stack Development.                                                                         │
# │  *   **Practice Mock Interviews:** Conduct mock technical and HR interviews to refine communication skills,     │
# │  articulate solutions clearly, and prepare for behavioral questions.                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  The journey to TCS Digital demands dedication, smart preparation, and a passion for technology. Start early,   │
# │  stay consistent, and showcase your unique digital expertise. Your future in innovation awaits – seize this     │
# │  incredible opportunity!                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Aiming for a rewarding career in cutting-edge tech? TCS Digital offers specialized roles, higher compensation, and a chance to innovate. Prepare smart, secure your future, and embark on a journey of digital transformation!
#
# ---
#
# ### 1. The Road to TCS Digital: Hiring Process
#
# The selection process is designed to identify top digital talent. Be prepared for a multi-stage evaluation:
#
# *   **Online Assessment:** Covers Quantitative Aptitude, Verbal Ability, Logical Reasoning, and Advanced Coding (expect 1-2 challenging problems).
# *   **Technical Interview:** Deep dive into Data Structures & Algorithms (DSA), programming language proficiency (Java/Python/C++), core CS subjects (OS, DBMS, Networking), and in-depth discussions on your projects.
# *   **Managerial Interview:** Evaluates your problem-solving approach, technical aptitude beyond just coding, leadership potential, and ability to handle project-specific scenarios.
# *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and handles discussions on compensation, location preferences, and joining formalities.
#
# ---
#
# ### 2. Your Digital Toolkit: Technical Stack
#
# TCS Digital roles demand proficiency in modern technologies. Focus on building expertise in these areas:
#
# *   **Programming Languages:** Strong command over Java, Python, or C++ with knowledge of relevant frameworks (e.g., Spring Boot, Django/Flask).
# *   **Cloud Technologies:** Familiarity with services from AWS, Azure, or GCP (e.g., compute, storage, serverless functions).
# *   **Data Science & AI/ML:** Understanding of machine learning concepts, data manipulation libraries (Pandas, NumPy), and ML frameworks (TensorFlow, PyTorch, Scikit-learn).
# *   **Web Technologies:** Knowledge of front-end frameworks (React, Angular, Vue.js) and back-end development principles.
# *   **Databases & DevOps:** Experience with SQL/NoSQL databases (e.g., MySQL, PostgreSQL, MongoDB) and basic DevOps concepts (Docker, Git).
#
# ---
#
# ### 3. Are You Eligible?
#
# Ensure you meet the basic academic and background criteria:
#
# *   **Academic Percentage:** A consistent record of 60% or 6.0 CGPA and above throughout 10th, 12th, and Graduation.
# *   **Degree:** Open to B.E./B.Tech/M.E./M.Tech/MCA students from specified branches (e.g., CSE, IT, ECE, EEE, Mechanical).
# *   **Year of Passing:** Primarily targets final-year students, but specific drives may include recent graduates.
# *   **Backlogs:** Candidates must not have any active backlogs at the time of appearing for the process.
# *   **Gap in Education:** A maximum academic gap of 1-2 years is usually permissible, but be prepared to explain it clearly.
#
# ---
#
# ### 4. What TCS Digital Looks For: Recent Hiring Trends
#
# Understand the evolving expectations of TCS Digital recruiters:
#
# *   **Focus on Digital Skills:** Strong emphasis on candidates demonstrating proficiency in cutting-edge technologies relevant to digital transformation.
# *   **Higher Compensation:** TCS Digital offers significantly higher packages compared to TCS Ninja roles, reflecting demand for specialized skills.
# *   **Problem-Solving Prowess:** Assessments increasingly prioritize advanced problem-solving, logical reasoning, and complex coding challenges.
# *   **Project-Based Evaluation:** More weight is given to real-world projects, internships, and certifications showcasing practical application of digital skills.
# *   **Agile & DevOps Mindset:** Recruiters seek candidates who understand agile methodologies and have an inclination towards DevOps practices.
#
# ---
#
# ### 5. Your Winning Strategy: Prep Tips
#
# Craft a focused preparation plan to excel in the TCS Digital process:
#
# *   **Master DSA & Competitive Programming:** Consistently practice Data Structures and Algorithms on platforms like LeetCode, HackerRank, or CodeChef, focusing on medium to hard problems.
# *   **Build Projects:** Develop 2-3 significant projects using modern technologies (e.g., web apps, AI/ML models, cloud deployments) to showcase practical skills.
# *   **Deep Dive into Core CS:** Strengthen fundamentals in Operating Systems, Database Management Systems, Computer Networks, and Object-Oriented Programming (OOPs) concepts.
# *   **Learn a Niche Technology:** Specialize in one or two in-demand areas like Cloud (AWS/Azure/GCP), Data Science/ML, or Full-Stack Development.
# *   **Practice Mock Interviews:** Conduct mock technical and HR interviews to refine communication skills, articulate solutions clearly, and prepare for behavioral questions.
#
# ---
#
# The journey to TCS Digital demands dedication, smart preparation, and a passion for technology. Start early, stay consistent, and showcase your unique digital expertise. Your future in innovation awaits – seize this incredible opportunity!

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 4782

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# **TCS Digital Placement Preparation for B.Tech Students**
#
# ### Hiring Process
# *   **Online Assessment:** Typically includes sections on quantitative aptitude, verbal ability, logical reasoning, and advanced coding (often 1-2 challenging problems).
# *   **Technical Interview:** Focuses on data structures and algorithms, programming language proficiency, core CS subjects (OS, DBMS, Networking), and project discussions.
# *   **Managerial Interview:** Evaluates problem-solving approach, technical aptitude beyond code, leadership potential, and ability to handle project-specific scenarios.
# *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and discusses compensation, location preferences, and joining formalities.
#
# ### Technical Stack
# *   **Programming Languages
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Aiming for a rewarding career in cutting-edge tech? TCS Digital offers specialized roles, higher compensation, and a chance to innovate. Prepare smart, secure your future, and embark on a journey of digital transformation!
#
# ---
#
# ### 1. The Road to TCS Digital: Hiring Process
#
# The selection process is designed to identify top digital talent. Be prepared for a multi-stage evaluation:
#
# *   **Online Assessment:** Covers Quantitative Aptitude, Verbal Ability, Logical Reasoning, and Advanced Coding (expect 1-2 challenging problems).
# *   **Technical Interview:** Deep dive into Data Structures & Algorithms (DSA), programming language proficiency (Java/Python/C++), core CS subjects (OS, DBMS, Networking), and in-depth discussions on your projects.
# *   **Manager

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")
